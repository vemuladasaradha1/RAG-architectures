# %% [markdown]
# # 14 — Self-RAG
# **What:** let the system reflect on retrieval and answer quality. **Why:** improve evidence discipline. **When:** unsupported answers are costly.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import SelfRAG
docs=docs_from_pairs([('Self','Self-RAG adds reflection signals around retrieval and generation.'),('Evidence','Evidence should support generated claims.')])
rag=SelfRAG(docs); query='What does Self-RAG add?'

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: implement explicit retrieve/critique/generate decisions with bounded loops and measurable reflection accuracy. No API key required.
