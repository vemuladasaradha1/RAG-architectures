# %% [markdown]
# # 05 — Reranking RAG
# **What:** retrieve broadly, then reorder candidates. **Why:** improve precision. **When:** top-k relevance is weak.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import RerankingRAG
docs=docs_from_pairs([('RAG','Retrieval augmented generation retrieves evidence.'),('Rerank','Rerankers reorder candidates using relevance.')])
rag=RerankingRAG(docs); query='How do rerankers reorder retrieved candidates?'

# %%
[(h.score,h.document.text) for h in rag.retrieve(query,3)]

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: replace the demo score with a cross-encoder reranker. No API key required.
