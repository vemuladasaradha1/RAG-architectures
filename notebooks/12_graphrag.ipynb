# %% [markdown]
# # 12 — GraphRAG
# **What:** retrieve using entities and relationships. **Why:** answer relationship-heavy questions and global corpus questions. **When:** entity connectivity matters.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import GraphRAG
docs=docs_from_pairs([('Graph','Knowledge graphs connect entities through relationships.'),('Company','Acme is headquartered in Paris.')])
rag=GraphRAG(docs); query='What relationships can a knowledge graph represent?'

# %%
[(h.score,h.document.text) for h in rag.retrieve(query,3)]

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: extract entities/relations, store a graph, and compare local/global graph retrieval with vector retrieval. No API key required.
