# %% [markdown]
# # 06 — Multi-Query RAG
# **What:** search multiple reformulations. **Why:** increase recall. **When:** ambiguous or underspecified user questions.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import MultiQueryRAG
docs=docs_from_pairs([('RAG','RAG retrieves evidence.'),('Recall','Multiple query formulations can improve recall.')])
rag=MultiQueryRAG(docs); query='How can query reformulation improve retrieval?'

# %%
[(h.score,h.document.text) for h in rag.retrieve(query,3)]

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: generate variants with a local LLM, retrieve in parallel, deduplicate, and optionally rerank. No API key required.
