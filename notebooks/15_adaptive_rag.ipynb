# %% [markdown]
# # 15 — Adaptive RAG
# **What:** route queries to different retrieval strategies. **Why:** one strategy is rarely optimal for every query. **When:** mixed workloads.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import AdaptiveRAG
docs=docs_from_pairs([('Short','BM25 works well for exact terms.'),('Long','Semantic retrieval helps paraphrased questions.')])
rag=AdaptiveRAG(docs); query='BM25 exact terms'

# %%
[(h.score,h.source,h.document.text) for h in rag.retrieve(query,3)]

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: route by query intent, complexity, latency budget or confidence; evaluate routing accuracy separately. No API key required.
