# %% [markdown]
# # 16 — Agentic RAG
# **What:** orchestrate retrieval, verification and answering as explicit steps. **Why:** handle complex workflows. **When:** simple one-pass RAG is insufficient.
#
# Steps: classify → retrieve → verify → answer.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import AgenticRAG
docs=docs_from_pairs([('Agent','Agentic RAG can plan and verify retrieval.'),('Evidence','Verification checks whether evidence supports the answer.')])
rag=AgenticRAG(docs); query='How can agentic RAG verify evidence?'

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: use LangGraph or an equivalent state-machine/orchestration layer, strict tool permissions, bounded iterations, timeouts and audit logs. No API key required.
