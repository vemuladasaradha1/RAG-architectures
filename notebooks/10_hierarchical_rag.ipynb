# %% [markdown]
# # 10 — Hierarchical RAG
# **What:** navigate from coarse summaries to fine evidence. **Why:** improve search over large corpora. **When:** corpus scale makes flat retrieval noisy.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import HierarchicalRAG
docs=docs_from_pairs([('Overview','This chapter explains retrieval systems.'),('Detail','Hierarchical retrieval searches coarse-to-fine.')])
rag=HierarchicalRAG(docs); query='How does hierarchical retrieval search?'

# %%
[(h.score,h.document.text) for h in rag.retrieve(query,3)]

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: build summary nodes at multiple levels and descend only into promising branches. No API key required.
