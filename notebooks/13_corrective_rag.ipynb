# %% [markdown]
# # 13 — Corrective RAG (CRAG)
# **What:** assess retrieval quality and correct weak retrieval. **Why:** reduce answers based on poor evidence. **When:** retrieval confidence varies widely.

# %%
from rag_architectures.core.pipeline import docs_from_pairs
from rag_architectures.architectures.all import CorrectiveRAG
docs=docs_from_pairs([('RAG','Corrective RAG evaluates evidence quality.'),('Fallback','Weak retrieval can trigger broader search.')])
rag=CorrectiveRAG(docs); query='What does corrective RAG evaluate?'

# %%
r=rag.run(query,3); print(r.answer); print(r.trace)

# %% [markdown]
# Production: define calibrated relevance thresholds and fallback routes; log every correction for evaluation. No API key required.
